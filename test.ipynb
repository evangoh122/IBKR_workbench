# %%
import duckdb
from pathlib import Path

db_path = Path(r"data\ibkr.duckdb")
con = duckdb.connect(str(db_path), read_only=True)

tables = con.execute("SHOW TABLES").fetchdf()
tables
# Out:
#                         name
# 0                cot_reports
# 1           edgar_embeddings
# 2                edgar_facts
# 3              edgar_filings
# 4                   etl_runs
# 5              option_chains
# 6              option_quotes
# 7               polygon_bars
# 8        polygon_option_bars
# 9   polygon_option_snapshots
# 10         polygon_snapshots
# 11           polygon_tickers
# 12            polygon_trades
# 13              stock_quotes
# 14         ticker_embeddings

# %%
tables
# Out:
#                         name
# 0                edgar_facts
# 1              edgar_filings
# 2                   etl_runs
# 3              option_chains
# 4              option_quotes
# 5               polygon_bars
# 6   polygon_option_snapshots
# 7          polygon_snapshots
# 8            polygon_tickers
# 9               stock_quotes
# 10         ticker_embeddings

# %%
# List all tables
con.execute("SHOW TABLES").df()

# Query the polygon tickers saved so far
con.execute("SELECT * FROM polygon_tickers").df()

# Check ETL run history
con.execute("SELECT * FROM etl_runs ORDER BY started_at DESC").df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # List all tables
# ----> 2 con.execute("SHOW TABLES").df()
#       4 # Query the polygon tickers saved so far
#       5 con.execute("SELECT * FROM polygon_tickers").df()
#
# NameError: name 'con' is not defined
